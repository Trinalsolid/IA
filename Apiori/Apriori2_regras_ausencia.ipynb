# %%
# Carregando a base de dados
import pandas as pd
from apyori import apriori

base = pd.read_csv('PãoeManteigaSimNao.csv', sep=';', encoding='cp1252', header=None)

# %%
# Obter todos os itens únicos da base
itens_unicos = set()
for i in range(len(base)):
    for j in range(base.shape[1]):
        item = str(base.values[i, j])
        if item != 'nan':
            itens_unicos.add(item)

# %%
# Criar transações com itens presentes e ausentes (~item)
transacoes = []
for i in range(len(base)):
    transacao = []
    itens_presentes = set()
    for j in range(base.shape[1]):
        item = str(base.values[i, j])
        if item != 'nan':
            transacao.append(item)
            itens_presentes.add(item)
    for item in itens_unicos:
        if item not in itens_presentes:
            transacao.append("~" + item)
    transacoes.append(transacao)

# %%
# Aplicar Apriori nas transações modificadas
regras = apriori(transacoes, min_support=0.3, min_confidence=0.8)
saida = list(regras)

# %%
# Exibir itemsets com suporte
print("Itemsets frequentes com suporte:")
for regra in saida:
    itens = list(regra.items)
    suporte = regra.support
    print(f"Itemset: {itens}, Suporte: {suporte:.2f}")
# Out:
# Itemsets frequentes com suporte:
# Itemset: ['NÃ£o'], Suporte: 1.00
# Itemset: ['~Arroz'], Suporte: 0.80
# Itemset: ['~Cerveja'], Suporte: 0.80
# Itemset: ['~FeijÃ£o'], Suporte: 0.80
# Itemset: ['~Leite'], Suporte: 0.80
# Itemset: ['Manteiga', 'CafÃ©'], Suporte: 0.30
# Itemset: ['NÃ£o', 'CafÃ©'], Suporte: 0.30
# Itemset: ['CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Arroz', 'CafÃ©'], Suporte: 0.30
# Itemset: ['~Cerveja', 'CafÃ©'], Suporte: 0.30
# Itemset: ['~FeijÃ£o', 'CafÃ©'], Suporte: 0.30
# Itemset: ['Manteiga', 'NÃ£o'], Suporte: 0.50
# Itemset: ['Manteiga', 'PÃ£o'], Suporte: 0.40
# Itemset: ['~Arroz', 'Manteiga'], Suporte: 0.50
# Itemset: ['Manteiga', '~Cerveja'], Suporte: 0.40
# Itemset: ['Manteiga', '~FeijÃ£o'], Suporte: 0.50
# Itemset: ['NÃ£o', 'PÃ£o'], Suporte: 0.50
# Itemset: ['~Arroz', 'NÃ£o'], Suporte: 0.80
# Itemset: ['NÃ£o', '~CafÃ©'], Suporte: 0.70
# Itemset: ['~Cerveja', 'NÃ£o'], Suporte: 0.80
# Itemset: ['NÃ£o', '~FeijÃ£o'], Suporte: 0.80
# Itemset: ['NÃ£o', '~Leite'], Suporte: 0.80
# Itemset: ['NÃ£o', '~Manteiga'], Suporte: 0.50
# Itemset: ['NÃ£o', '~PÃ£o'], Suporte: 0.50
# Itemset: ['~Arroz', 'PÃ£o'], Suporte: 0.50
# Itemset: ['~Cerveja', 'PÃ£o'], Suporte: 0.40
# Itemset: ['~FeijÃ£o', 'PÃ£o'], Suporte: 0.50
# Itemset: ['~Arroz', '~FeijÃ£o'], Suporte: 0.70
# Itemset: ['~Leite', '~CafÃ©'], Suporte: 0.60
# Itemset: ['~Manteiga', '~CafÃ©'], Suporte: 0.50
# Itemset: ['~PÃ£o', '~CafÃ©'], Suporte: 0.50
# Itemset: ['~Cerveja', '~Leite'], Suporte: 0.70
# Itemset: ['~Cerveja', '~Manteiga'], Suporte: 0.40
# Itemset: ['~Cerveja', '~PÃ£o'], Suporte: 0.40
# Itemset: ['~Leite', '~Manteiga'], Suporte: 0.50
# Itemset: ['~Leite', '~PÃ£o'], Suporte: 0.50
# Itemset: ['~PÃ£o', '~Manteiga'], Suporte: 0.40
# Itemset: ['Manteiga', 'NÃ£o', 'CafÃ©'], Suporte: 0.30
# Itemset: ['Manteiga', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Arroz', 'Manteiga', 'CafÃ©'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', 'CafÃ©'], Suporte: 0.30
# Itemset: ['Manteiga', '~FeijÃ£o', 'CafÃ©'], Suporte: 0.30
# Itemset: ['NÃ£o', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Arroz', 'NÃ£o', 'CafÃ©'], Suporte: 0.30
# Itemset: ['~Cerveja', 'NÃ£o', 'CafÃ©'], Suporte: 0.30
# Itemset: ['NÃ£o', '~FeijÃ£o', 'CafÃ©'], Suporte: 0.30
# Itemset: ['~Arroz', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Cerveja', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~FeijÃ£o', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Arroz', '~Cerveja', 'CafÃ©'], Suporte: 0.30
# Itemset: ['~Arroz', '~FeijÃ£o', 'CafÃ©'], Suporte: 0.30
# Itemset: ['~Cerveja', '~FeijÃ£o', 'CafÃ©'], Suporte: 0.30
# Itemset: ['Manteiga', 'NÃ£o', 'PÃ£o'], Suporte: 0.40
# Itemset: ['~Arroz', 'Manteiga', 'NÃ£o'], Suporte: 0.50
# Itemset: ['Manteiga', '~Cerveja', 'NÃ£o'], Suporte: 0.40
# Itemset: ['Manteiga', 'NÃ£o', '~FeijÃ£o'], Suporte: 0.50
# Itemset: ['Manteiga', 'NÃ£o', '~Leite'], Suporte: 0.30
# Itemset: ['~Arroz', 'Manteiga', 'PÃ£o'], Suporte: 0.40
# Itemset: ['Manteiga', '~FeijÃ£o', 'PÃ£o'], Suporte: 0.40
# Itemset: ['~Arroz', 'Manteiga', '~Cerveja'], Suporte: 0.40
# Itemset: ['~Arroz', 'Manteiga', '~FeijÃ£o'], Suporte: 0.50
# Itemset: ['~Arroz', 'Manteiga', '~Leite'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', '~FeijÃ£o'], Suporte: 0.40
# Itemset: ['Manteiga', '~Cerveja', '~Leite'], Suporte: 0.30
# Itemset: ['Manteiga', '~FeijÃ£o', '~Leite'], Suporte: 0.30
# Itemset: ['~Arroz', 'NÃ£o', 'PÃ£o'], Suporte: 0.50
# Itemset: ['~Cerveja', 'NÃ£o', 'PÃ£o'], Suporte: 0.40
# Itemset: ['NÃ£o', '~FeijÃ£o', 'PÃ£o'], Suporte: 0.50
# Itemset: ['NÃ£o', '~Leite', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Arroz', 'NÃ£o', '~CafÃ©'], Suporte: 0.50
# Itemset: ['~Arroz', '~Cerveja', 'NÃ£o'], Suporte: 0.60
# Itemset: ['~Arroz', 'NÃ£o', '~FeijÃ£o'], Suporte: 0.70
# Itemset: ['~Arroz', 'NÃ£o', '~Leite'], Suporte: 0.60
# Itemset: ['~Arroz', 'NÃ£o', '~Manteiga'], Suporte: 0.30
# Itemset: ['~Arroz', 'NÃ£o', '~PÃ£o'], Suporte: 0.30
# Itemset: ['~Cerveja', 'NÃ£o', '~CafÃ©'], Suporte: 0.50
# Itemset: ['NÃ£o', '~FeijÃ£o', '~CafÃ©'], Suporte: 0.50
# Itemset: ['NÃ£o', '~Leite', '~CafÃ©'], Suporte: 0.60
# Itemset: ['NÃ£o', '~Manteiga', '~CafÃ©'], Suporte: 0.50
# Itemset: ['NÃ£o', '~PÃ£o', '~CafÃ©'], Suporte: 0.50
# Itemset: ['~Cerveja', 'NÃ£o', '~FeijÃ£o'], Suporte: 0.60
# Itemset: ['~Cerveja', 'NÃ£o', '~Leite'], Suporte: 0.70
# Itemset: ['~Cerveja', 'NÃ£o', '~Manteiga'], Suporte: 0.40
# Itemset: ['~Cerveja', 'NÃ£o', '~PÃ£o'], Suporte: 0.40
# Itemset: ['NÃ£o', '~FeijÃ£o', '~Leite'], Suporte: 0.60
# Itemset: ['NÃ£o', '~FeijÃ£o', '~Manteiga'], Suporte: 0.30
# Itemset: ['NÃ£o', '~FeijÃ£o', '~PÃ£o'], Suporte: 0.30
# Itemset: ['NÃ£o', '~Leite', '~Manteiga'], Suporte: 0.50
# Itemset: ['NÃ£o', '~Leite', '~PÃ£o'], Suporte: 0.50
# Itemset: ['NÃ£o', '~PÃ£o', '~Manteiga'], Suporte: 0.40
# Itemset: ['~Arroz', '~Cerveja', 'PÃ£o'], Suporte: 0.40
# Itemset: ['~Arroz', '~FeijÃ£o', 'PÃ£o'], Suporte: 0.50
# Itemset: ['~Arroz', '~Leite', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Cerveja', '~FeijÃ£o', 'PÃ£o'], Suporte: 0.40
# Itemset: ['~Cerveja', '~Leite', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~FeijÃ£o', '~Leite', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Arroz', '~FeijÃ£o', '~CafÃ©'], Suporte: 0.40
# Itemset: ['~Arroz', '~Leite', '~CafÃ©'], Suporte: 0.40
# Itemset: ['~Arroz', '~Manteiga', '~CafÃ©'], Suporte: 0.30
# Itemset: ['~Arroz', '~PÃ£o', '~CafÃ©'], Suporte: 0.30
# Itemset: ['~Arroz', '~Cerveja', '~FeijÃ£o'], Suporte: 0.50
# Itemset: ['~Arroz', '~Cerveja', '~Leite'], Suporte: 0.50
# Itemset: ['~Arroz', '~FeijÃ£o', '~Leite'], Suporte: 0.50
# Itemset: ['~Arroz', '~Leite', '~Manteiga'], Suporte: 0.30
# Itemset: ['~Arroz', '~Leite', '~PÃ£o'], Suporte: 0.30
# Itemset: ['~Cerveja', '~Leite', '~CafÃ©'], Suporte: 0.50
# Itemset: ['~Cerveja', '~Manteiga', '~CafÃ©'], Suporte: 0.40
# Itemset: ['~Cerveja', '~PÃ£o', '~CafÃ©'], Suporte: 0.40
# Itemset: ['~FeijÃ£o', '~Leite', '~CafÃ©'], Suporte: 0.40
# Itemset: ['~FeijÃ£o', '~Manteiga', '~CafÃ©'], Suporte: 0.30
# Itemset: ['~FeijÃ£o', '~PÃ£o', '~CafÃ©'], Suporte: 0.30
# Itemset: ['~Leite', '~Manteiga', '~CafÃ©'], Suporte: 0.50
# Itemset: ['~Leite', '~PÃ£o', '~CafÃ©'], Suporte: 0.50
# Itemset: ['~PÃ£o', '~Manteiga', '~CafÃ©'], Suporte: 0.40
# Itemset: ['~Cerveja', '~FeijÃ£o', '~Leite'], Suporte: 0.50
# Itemset: ['~Cerveja', '~Leite', '~Manteiga'], Suporte: 0.40
# Itemset: ['~Cerveja', '~Leite', '~PÃ£o'], Suporte: 0.40
# Itemset: ['~FeijÃ£o', '~Leite', '~Manteiga'], Suporte: 0.30
# Itemset: ['~FeijÃ£o', '~Leite', '~PÃ£o'], Suporte: 0.30
# Itemset: ['~Leite', '~PÃ£o', '~Manteiga'], Suporte: 0.40
# Itemset: ['Manteiga', 'NÃ£o', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Arroz', 'Manteiga', 'NÃ£o', 'CafÃ©'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', 'NÃ£o', 'CafÃ©'], Suporte: 0.30
# Itemset: ['Manteiga', 'NÃ£o', '~FeijÃ£o', 'CafÃ©'], Suporte: 0.30
# Itemset: ['~Arroz', 'Manteiga', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['Manteiga', '~FeijÃ£o', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Arroz', 'Manteiga', '~Cerveja', 'CafÃ©'], Suporte: 0.30
# Itemset: ['~Arroz', 'Manteiga', '~FeijÃ£o', 'CafÃ©'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', '~FeijÃ£o', 'CafÃ©'], Suporte: 0.30
# Itemset: ['~Arroz', 'NÃ£o', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Cerveja', 'NÃ£o', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['NÃ£o', '~FeijÃ£o', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Arroz', '~Cerveja', 'NÃ£o', 'CafÃ©'], Suporte: 0.30
# Itemset: ['~Arroz', 'NÃ£o', '~FeijÃ£o', 'CafÃ©'], Suporte: 0.30
# Itemset: ['~Cerveja', 'NÃ£o', '~FeijÃ£o', 'CafÃ©'], Suporte: 0.30
# Itemset: ['~Arroz', '~Cerveja', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Arroz', '~FeijÃ£o', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Cerveja', '~FeijÃ£o', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Arroz', '~Cerveja', '~FeijÃ£o', 'CafÃ©'], Suporte: 0.30
# Itemset: ['~Arroz', 'Manteiga', 'NÃ£o', 'PÃ£o'], Suporte: 0.40
# Itemset: ['Manteiga', '~Cerveja', 'NÃ£o', 'PÃ£o'], Suporte: 0.30
# Itemset: ['Manteiga', 'NÃ£o', '~FeijÃ£o', 'PÃ£o'], Suporte: 0.40
# Itemset: ['~Arroz', 'Manteiga', '~Cerveja', 'NÃ£o'], Suporte: 0.40
# Itemset: ['~Arroz', 'Manteiga', 'NÃ£o', '~FeijÃ£o'], Suporte: 0.50
# Itemset: ['~Arroz', 'Manteiga', 'NÃ£o', '~Leite'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', 'NÃ£o', '~FeijÃ£o'], Suporte: 0.40
# Itemset: ['Manteiga', '~Cerveja', 'NÃ£o', '~Leite'], Suporte: 0.30
# Itemset: ['Manteiga', 'NÃ£o', '~FeijÃ£o', '~Leite'], Suporte: 0.30
# Itemset: ['~Arroz', 'Manteiga', '~Cerveja', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Arroz', 'Manteiga', '~FeijÃ£o', 'PÃ£o'], Suporte: 0.40
# Itemset: ['Manteiga', '~Cerveja', '~FeijÃ£o', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Arroz', 'Manteiga', '~Cerveja', '~FeijÃ£o'], Suporte: 0.40
# Itemset: ['~Arroz', 'Manteiga', '~Cerveja', '~Leite'], Suporte: 0.30
# Itemset: ['~Arroz', 'Manteiga', '~FeijÃ£o', '~Leite'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', '~FeijÃ£o', '~Leite'], Suporte: 0.30
# Itemset: ['~Arroz', '~Cerveja', 'NÃ£o', 'PÃ£o'], Suporte: 0.40
# Itemset: ['~Arroz', 'NÃ£o', '~FeijÃ£o', 'PÃ£o'], Suporte: 0.50
# Itemset: ['~Arroz', 'NÃ£o', '~Leite', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Cerveja', 'NÃ£o', '~FeijÃ£o', 'PÃ£o'], Suporte: 0.40
# Itemset: ['~Cerveja', 'NÃ£o', '~Leite', 'PÃ£o'], Suporte: 0.30
# Itemset: ['NÃ£o', '~FeijÃ£o', '~Leite', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Arroz', '~Cerveja', 'NÃ£o', '~CafÃ©'], Suporte: 0.30
# Itemset: ['~Arroz', 'NÃ£o', '~FeijÃ£o', '~CafÃ©'], Suporte: 0.40
# Itemset: ['~Arroz', 'NÃ£o', '~Leite', '~CafÃ©'], Suporte: 0.40
# Itemset: ['~Arroz', 'NÃ£o', '~Manteiga', '~CafÃ©'], Suporte: 0.30
# Itemset: ['~Arroz', 'NÃ£o', '~PÃ£o', '~CafÃ©'], Suporte: 0.30
# Itemset: ['~Arroz', '~Cerveja', 'NÃ£o', '~FeijÃ£o'], Suporte: 0.50
# Itemset: ['~Arroz', '~Cerveja', 'NÃ£o', '~Leite'], Suporte: 0.50
# Itemset: ['~Arroz', 'NÃ£o', '~FeijÃ£o', '~Leite'], Suporte: 0.50
# Itemset: ['~Arroz', 'NÃ£o', '~Leite', '~Manteiga'], Suporte: 0.30
# Itemset: ['~Arroz', 'NÃ£o', '~Leite', '~PÃ£o'], Suporte: 0.30
# Itemset: ['~Cerveja', 'NÃ£o', '~FeijÃ£o', '~CafÃ©'], Suporte: 0.30
# Itemset: ['~Cerveja', 'NÃ£o', '~Leite', '~CafÃ©'], Suporte: 0.50
# Itemset: ['~Cerveja', 'NÃ£o', '~Manteiga', '~CafÃ©'], Suporte: 0.40
# Itemset: ['~Cerveja', 'NÃ£o', '~PÃ£o', '~CafÃ©'], Suporte: 0.40
# Itemset: ['NÃ£o', '~FeijÃ£o', '~Leite', '~CafÃ©'], Suporte: 0.40
# Itemset: ['NÃ£o', '~FeijÃ£o', '~Manteiga', '~CafÃ©'], Suporte: 0.30
# Itemset: ['NÃ£o', '~FeijÃ£o', '~PÃ£o', '~CafÃ©'], Suporte: 0.30
# Itemset: ['NÃ£o', '~Leite', '~Manteiga', '~CafÃ©'], Suporte: 0.50
# Itemset: ['NÃ£o', '~Leite', '~PÃ£o', '~CafÃ©'], Suporte: 0.50
# Itemset: ['NÃ£o', '~PÃ£o', '~Manteiga', '~CafÃ©'], Suporte: 0.40
# Itemset: ['~Cerveja', 'NÃ£o', '~FeijÃ£o', '~Leite'], Suporte: 0.50
# Itemset: ['~Cerveja', 'NÃ£o', '~Leite', '~Manteiga'], Suporte: 0.40
# Itemset: ['~Cerveja', 'NÃ£o', '~Leite', '~PÃ£o'], Suporte: 0.40
# Itemset: ['~Cerveja', 'NÃ£o', '~PÃ£o', '~Manteiga'], Suporte: 0.30
# Itemset: ['NÃ£o', '~FeijÃ£o', '~Leite', '~Manteiga'], Suporte: 0.30
# Itemset: ['NÃ£o', '~FeijÃ£o', '~Leite', '~PÃ£o'], Suporte: 0.30
# Itemset: ['NÃ£o', '~Leite', '~Manteiga', '~PÃ£o'], Suporte: 0.40
# Itemset: ['~Arroz', '~Cerveja', '~FeijÃ£o', 'PÃ£o'], Suporte: 0.40
# Itemset: ['~Arroz', '~Cerveja', '~Leite', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Arroz', '~FeijÃ£o', '~Leite', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Cerveja', '~FeijÃ£o', '~Leite', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Arroz', '~Cerveja', '~Leite', '~CafÃ©'], Suporte: 0.30
# Itemset: ['~Arroz', '~Leite', '~Manteiga', '~CafÃ©'], Suporte: 0.30
# Itemset: ['~Arroz', '~Leite', '~PÃ£o', '~CafÃ©'], Suporte: 0.30
# Itemset: ['~Arroz', '~Cerveja', '~FeijÃ£o', '~Leite'], Suporte: 0.40
# Itemset: ['~Cerveja', '~FeijÃ£o', '~Leite', '~CafÃ©'], Suporte: 0.30
# Itemset: ['~Cerveja', '~Leite', '~Manteiga', '~CafÃ©'], Suporte: 0.40
# Itemset: ['~Cerveja', '~Leite', '~PÃ£o', '~CafÃ©'], Suporte: 0.40
# Itemset: ['~Cerveja', '~PÃ£o', '~Manteiga', '~CafÃ©'], Suporte: 0.30
# Itemset: ['~FeijÃ£o', '~Leite', '~Manteiga', '~CafÃ©'], Suporte: 0.30
# Itemset: ['~FeijÃ£o', '~Leite', '~PÃ£o', '~CafÃ©'], Suporte: 0.30
# Itemset: ['~Leite', '~PÃ£o', '~Manteiga', '~CafÃ©'], Suporte: 0.40
# Itemset: ['~Cerveja', '~Leite', '~Manteiga', '~PÃ£o'], Suporte: 0.30
# Itemset: ['Manteiga', 'NÃ£o', 'CafÃ©', '~Arroz', 'PÃ£o'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', 'NÃ£o', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['Manteiga', 'NÃ£o', '~FeijÃ£o', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', 'NÃ£o', 'CafÃ©', '~Arroz'], Suporte: 0.30
# Itemset: ['Manteiga', 'NÃ£o', '~FeijÃ£o', 'CafÃ©', '~Arroz'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', 'NÃ£o', '~FeijÃ£o', 'CafÃ©'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', 'CafÃ©', '~Arroz', 'PÃ£o'], Suporte: 0.30
# Itemset: ['Manteiga', '~FeijÃ£o', 'CafÃ©', '~Arroz', 'PÃ£o'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', '~FeijÃ£o', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', '~FeijÃ£o', 'CafÃ©', '~Arroz'], Suporte: 0.30
# Itemset: ['~Cerveja', 'NÃ£o', 'CafÃ©', '~Arroz', 'PÃ£o'], Suporte: 0.30
# Itemset: ['NÃ£o', '~FeijÃ£o', 'CafÃ©', '~Arroz', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Cerveja', 'NÃ£o', '~FeijÃ£o', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Cerveja', 'NÃ£o', '~FeijÃ£o', 'CafÃ©', '~Arroz'], Suporte: 0.30
# Itemset: ['~Cerveja', '~FeijÃ£o', 'CafÃ©', '~Arroz', 'PÃ£o'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', 'NÃ£o', '~Arroz', 'PÃ£o'], Suporte: 0.30
# Itemset: ['Manteiga', 'NÃ£o', '~FeijÃ£o', '~Arroz', 'PÃ£o'], Suporte: 0.40
# Itemset: ['Manteiga', '~Cerveja', 'NÃ£o', '~FeijÃ£o', 'PÃ£o'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', 'NÃ£o', '~FeijÃ£o', '~Arroz'], Suporte: 0.40
# Itemset: ['Manteiga', '~Cerveja', 'NÃ£o', '~Arroz', '~Leite'], Suporte: 0.30
# Itemset: ['Manteiga', 'NÃ£o', '~FeijÃ£o', '~Arroz', '~Leite'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', 'NÃ£o', '~FeijÃ£o', '~Leite'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', '~FeijÃ£o', '~Arroz', 'PÃ£o'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', '~FeijÃ£o', '~Arroz', '~Leite'], Suporte: 0.30
# Itemset: ['~Cerveja', 'NÃ£o', '~FeijÃ£o', '~Arroz', 'PÃ£o'], Suporte: 0.40
# Itemset: ['~Cerveja', 'NÃ£o', '~Arroz', '~Leite', 'PÃ£o'], Suporte: 0.30
# Itemset: ['NÃ£o', '~FeijÃ£o', '~Arroz', '~Leite', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Cerveja', 'NÃ£o', '~FeijÃ£o', '~Leite', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Cerveja', 'NÃ£o', '~CafÃ©', '~Arroz', '~Leite'], Suporte: 0.30
# Itemset: ['NÃ£o', '~FeijÃ£o', '~CafÃ©', '~Arroz', '~Leite'], Suporte: 0.30
# Itemset: ['NÃ£o', '~CafÃ©', '~Arroz', '~Leite', '~Manteiga'], Suporte: 0.30
# Itemset: ['NÃ£o', '~PÃ£o', '~CafÃ©', '~Arroz', '~Leite'], Suporte: 0.30
# Itemset: ['~Cerveja', 'NÃ£o', '~FeijÃ£o', '~Arroz', '~Leite'], Suporte: 0.40
# Itemset: ['~Cerveja', 'NÃ£o', '~FeijÃ£o', '~CafÃ©', '~Leite'], Suporte: 0.30
# Itemset: ['~Cerveja', 'NÃ£o', '~CafÃ©', '~Leite', '~Manteiga'], Suporte: 0.40
# Itemset: ['~Cerveja', 'NÃ£o', '~PÃ£o', '~CafÃ©', '~Leite'], Suporte: 0.40
# Itemset: ['~Cerveja', 'NÃ£o', '~PÃ£o', '~CafÃ©', '~Manteiga'], Suporte: 0.30
# Itemset: ['NÃ£o', '~FeijÃ£o', '~CafÃ©', '~Leite', '~Manteiga'], Suporte: 0.30
# Itemset: ['NÃ£o', '~FeijÃ£o', '~PÃ£o', '~CafÃ©', '~Leite'], Suporte: 0.30
# Itemset: ['NÃ£o', '~PÃ£o', '~CafÃ©', '~Leite', '~Manteiga'], Suporte: 0.40
# Itemset: ['~Cerveja', 'NÃ£o', '~PÃ£o', '~Leite', '~Manteiga'], Suporte: 0.30
# Itemset: ['~Cerveja', '~FeijÃ£o', '~Arroz', '~Leite', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Cerveja', '~PÃ£o', '~CafÃ©', '~Leite', '~Manteiga'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', 'NÃ£o', 'CafÃ©', '~Arroz', 'PÃ£o'], Suporte: 0.30
# Itemset: ['Manteiga', 'NÃ£o', '~FeijÃ£o', 'CafÃ©', '~Arroz', 'PÃ£o'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', 'NÃ£o', '~FeijÃ£o', 'CafÃ©', 'PÃ£o'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', 'NÃ£o', '~FeijÃ£o', 'CafÃ©', '~Arroz'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', '~FeijÃ£o', 'CafÃ©', '~Arroz', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Cerveja', 'NÃ£o', '~FeijÃ£o', 'CafÃ©', '~Arroz', 'PÃ£o'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', 'NÃ£o', '~FeijÃ£o', '~Arroz', 'PÃ£o'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', 'NÃ£o', '~FeijÃ£o', '~Arroz', '~Leite'], Suporte: 0.30
# Itemset: ['~Cerveja', 'NÃ£o', '~FeijÃ£o', '~Arroz', '~Leite', 'PÃ£o'], Suporte: 0.30
# Itemset: ['~Cerveja', 'NÃ£o', '~PÃ£o', '~CafÃ©', '~Leite', '~Manteiga'], Suporte: 0.30
# Itemset: ['Manteiga', '~Cerveja', 'NÃ£o', '~FeijÃ£o', 'CafÃ©', '~Arroz', 'PÃ£o'], Suporte: 0.30

# %%
# Extrair e exibir regras de associação incluindo itens ausentes
Antecedente = []
Consequente = []
suporte = []
confianca = []
lift = []

for resultado in saida:
    s = resultado[1]
    result_rules = resultado[2]
    for result_rule in result_rules:
        a = list(result_rule[0])
        b = list(result_rule[1])
        c = result_rule[2]
        l = result_rule[3]
        if 'nan' in a or 'nan' in b: continue
        if len(a) == 0 or len(b) == 0: continue
        Antecedente.append(a)
        Consequente.append(b)
        suporte.append(s)
        confianca.append(c)
        lift.append(l)

RegrasFinais = pd.DataFrame({'Antecedente': Antecedente, 'Consequente': Consequente,
                              'suporte': suporte, 'confianca': confianca, 'lift': lift})
print(RegrasFinais)
# Out:
#                                             Antecedente Consequente  suporte  \
# 0                                               [CafÃ©]  [Manteiga]      0.3
# 1                                               [CafÃ©]      [NÃ£o]      0.3
# 2                                               [CafÃ©]      [PÃ£o]      0.3
# 3                                               [CafÃ©]    [~Arroz]      0.3
# 4                                               [CafÃ©]  [~Cerveja]      0.3
# ...                                                 ...         ...      ...
# 1475  [Manteiga, ~Cerveja, NÃ£o, ~FeijÃ£o, CafÃ©, PÃ£o]    [~Arroz]      0.3
# 1476  [Manteiga, ~Cerveja, NÃ£o, ~FeijÃ£o, CafÃ©, ~A...      [PÃ£o]      0.3
# 1477  [Manteiga, ~Cerveja, ~FeijÃ£o, CafÃ©, ~Arroz, ...      [NÃ£o]      0.3
# 1478    [~Cerveja, NÃ£o, ~FeijÃ£o, CafÃ©, ~Arroz, PÃ£o]  [Manteiga]      0.3
# 1479  [Manteiga, ~Cerveja, NÃ£o, ~FeijÃ£o, ~Arroz, P...     [CafÃ©]      0.3
#
#       confianca      lift
# 0           1.0  2.000000
# 1           1.0  1.000000
# 2           1.0  2.000000
# 3           1.0  1.250000
# 4           1.0  1.250000
# ...         ...       ...
# 1475        1.0  1.250000
# 1476        1.0  2.000000
# 1477        1.0  1.000000
# 1478        1.0  2.000000
# 1479        1.0  3.333333
#
# [1480 rows x 5 columns]
